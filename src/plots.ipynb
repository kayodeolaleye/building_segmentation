# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %matplotlib inline

# %%
#history data for 0.122% distribution
history1 = pickle.load(open('../data/output/22_10_2017_1351_sentinel_one_layer/history.pickle', 'rb')) #sw=16
history2 = pickle.load(open('../data/output/23_10_2017_0931_sentinel_one_layer/history.pickle', 'rb')) #sw=32
history3 = pickle.load(open('../data/output/23_10_2017_1405_sentinel_one_layer/history.pickle', 'rb')) #sw=64

#history data for 5% distribution
history4 = pickle.load(open('../data/output/06_11_2017_1807_sentinel_one_layer/history.pickle', 'rb')) #sw=16
history5 = pickle.load(open('../data/output/07_11_2017_1446_sentinel_one_layer/history.pickle', 'rb')) #sw=32
history6 = pickle.load(open('../data/output/08_11_2017_0841_sentinel_one_layer/history.pickle', 'rb')) #sw=64

# %%
#prec-recall data for 0.122% distribution
pr1 = pickle.load(open('../data/output/22_10_2017_1351_sentinel_one_layer/precision_recall.pickle', 'rb')) #sw=16
pr2 = pickle.load(open('../data/output/23_10_2017_0931_sentinel_one_layer/precision_recall.pickle', 'rb')) #sw=32
pr3 = pickle.load(open('../data/output/23_10_2017_1405_sentinel_one_layer/precision_recall.pickle', 'rb')) #sw=64

#prec-recall data for 5% distribution
pr4 = pickle.load(open('../data/output/06_11_2017_1807_sentinel_one_layer/precision_recall.pickle', 'rb')) #sw=16
pr5 = pickle.load(open('../data/output/07_11_2017_1446_sentinel_one_layer/precision_recall.pickle', 'rb')) #sw=32
pr6 = pickle.load(open('../data/output/08_11_2017_0841_sentinel_one_layer/precision_recall.pickle', 'rb')) #sw=64

# %%
# dist=0.122%, sw=16
prec1 = pr1['precision']
rec1 = pr1['recall']  
# dist=0.122%, sw=32
rec2 = pr2['recall']  
prec2 = pr2['precision']
# dist=0.122%, sw=64
rec3 = pr3['recall']  
prec3 = pr3['precision']
# dist=5%, sw=16
rec4 = pr4['recall']  
prec4 = pr4['precision']
# dist=5%, sw=32
rec5 = pr5['recall']  
prec5 = pr5['precision']
# dist=5%, sw=64
rec6 = pr6['recall']  
prec6 = pr6['precision']

# %%
# dist=0.122%, sw=16
acc1 = history1['acc']
val_acc1 = history1['val_acc']
# dist=0.122%, sw=32
acc2 = history2['acc']
val_acc2 = history2['val_acc']
# dist=0.122%, sw=64
acc3 = history3['acc']
val_acc3 = history3['val_acc']
# dist=5%, sw=16
acc4 = history4['acc']
val_acc4 = history4['val_acc']
# dist=5%, sw=32
acc5 = history5['acc']
val_acc5 = history5['val_acc']
# dist=5%, sw=64
acc6 = history6['acc']
val_acc6 = history6['val_acc']

# %% [markdown]
# ### Precision-recall Plot of dist=0.122%, sliding windows: 16, 32 and 64

# %%
plt.plot(rec1, prec1, '', linestyle='dashed', label='atleast 0.122% of patch contains building pixels. sliding window=16')
plt.plot(rec2, prec2, '', linestyle='dashed', label='atleast 0.122% of patch contains building pixels. sliding window=32')
plt.plot(rec3, prec3, '', linestyle='dashed', label='atleast 0.122% of patch contains building pixels. sliding window=64')
#plt.plot(rec4, prec4, '', label='atleast 10% of patch contains building pixels')
#plt.plot(rec5, prec5, '', label='5 building pixels in patch with sliding window 32')
#plt.plot(rec6, prec6, '', label='5 building pixels in patch with sliding window 16')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.19),
          fancybox=True, shadow=True)
plt.xlabel('recall')
plt.ylabel('precision')
plt.title("Precision-Recall Curve for Different Sliding window")
plt.xlim(0, 1, 0.2)
plt.ylim(0, 1, 0.2)
plt.savefig('../data/output/pr1.png')

# %% [markdown]
# ### Precision-recall Plot of dist=0.122%, 5%, 10%, 20% and sliding windows: 16, 32 and 64

# %%
plt.plot(rec1, prec1, '', linestyle='dashed', label='atleast 0.122% of patch contains building pixels. sliding window=16')
plt.plot(rec2, prec2, '', linestyle='dashed', label='atleast 0.122% of patch contains building pixels. sliding window=32')
plt.plot(rec3, prec3, '', linestyle='dashed', label='atleast 0.122% of patch contains building pixels. sliding window=64')
plt.plot(rec4, prec4, '', linestyle='dashed', label='atleast 5% of patch contains building pixels. sliding window=16')
#plt.plot(rec5, prec5, '', label='5 building pixels in patch with sliding window 32')
#plt.plot(rec6, prec6, '', label='5 building pixels in patch with sliding window 16')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.19),
          fancybox=True, shadow=True)
plt.xlabel('recall')
plt.ylabel('precision')
plt.title("Precision-Recall Curve for Different Sliding window")
plt.xlim(0, 1, 0.2)
plt.ylim(0, 1, 0.2)
plt.savefig('../data/output/pr1.png')

# %% [markdown]
# ### Precision-recall plot of dist=5%, sliding windows: 16, 32 and 64

# %%
plt.plot(rec4, prec4, '', linestyle='dashed', label='atleast 5% of patch contains building pixels. sliding window=16')
plt.plot(rec5, prec5, '', linestyle='dashed', label='atleast 5% of patch contains building pixels. sliding window=32')
plt.plot(rec6, prec6, '', linestyle='dashed', label='atleast 5% of patch contains building pixels. sliding window=64')

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.19),
          fancybox=True, shadow=True)
plt.xlabel('recall')
plt.ylabel('precision')
plt.title("Precision-Recall Curve for Different Sliding window")
plt.xlim(0, 1, 0.2)
plt.ylim(0, 1, 0.2)
plt.savefig('../data/output/plot_dist_5_sw_16_32_64.png')

# %% [markdown]
# ### Precision-recall Plot of dist=0.122%, 5%, 10%, 20% and sliding windows: 16

# %%
plt.plot(rec1, prec1, '', linestyle='dashed', label='atleast 0.122% of patch contains building pixels. sliding window=16')
#plt.plot(rec2, prec2, '', linestyle='dashed', label='atleast 0.122% of patch contains building pixels. sliding window=32')
#plt.plot(rec3, prec3, '', linestyle='dashed', label='atleast 0.122% of patch contains building pixels. sliding window=64')
plt.plot(rec4, prec4, '', linestyle='dashed', label='atleast 5% of patch contains building pixels. sliding window=16')
#plt.plot(rec5, prec5, '', label='5 building pixels in patch with sliding window 32')
#plt.plot(rec6, prec6, '', label='5 building pixels in patch with sliding window 16')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.19),
          fancybox=True, shadow=True)
plt.xlabel('recall')
plt.ylabel('precision')
plt.title("Precision-Recall Curve for Different Sliding window")
plt.xlim(0, 1, 0.2)
plt.ylim(0, 1, 0.2)
plt.savefig('../data/output/pr1.png')

# %% [markdown]
# ### Accuracy Plot of dist=0.122%, 5%, sliding windows: 16

# %%
plt.plot(acc1, '', linestyle='dashed', marker='.', label='train(0.122% building pixels with sliding window=16)')
plt.plot(val_acc1, '', linestyle='dashed', marker='.', label='validation(0.122% building pixels with sliding window=16)')

plt.plot(acc4, '', linestyle='dashed', marker='.', label='train(5% building pixels with sliding window=16)')
plt.plot(val_acc4, '', linestyle='dashed', marker='.', label='validation(5% building pixels with sliding window=16)')

#plt.plot(acc3, '', linestyle='dashed', marker='.', label='train(0.122% building pixels with sliding window=64)')
#plt.plot(val_acc3, '', linestyle='dashed', marker='.', label='validation(0.122% building pixels with sliding window=64)')

#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.19),
          fancybox=True, shadow=True)
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.title("Model Accuracy for different Data Samples")
#plt.xlim(0, 4, 0.2)
#plt.ylim(0, 1, 0.01)

# %% [markdown]
# ### Accuracy Plot of dist=0.122%, sliding windows: 16, 32, 64

# %%
plt.plot(acc1, '', linestyle='dashed', marker='.', label='train(0.122% building pixels with sliding window=16)')
plt.plot(val_acc1, '', linestyle='dashed', marker='.', label='validation(0.122% building pixels with sliding window=16)')

plt.plot(acc2, '', linestyle='dashed', marker='.', label='train(0.122% building pixels with sliding window=32)')
plt.plot(val_acc2, '', linestyle='dashed', marker='.', label='validation(0.122% building pixels with sliding window=32)')

plt.plot(acc3, '', linestyle='dashed', marker='.', label='train(0.122% building pixels with sliding window=64)')
plt.plot(val_acc3, '', linestyle='dashed', marker='.', label='validation(0.122% building pixels with sliding window=64)')

#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.19),
          fancybox=True, shadow=True)
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.title("Model Accuracy for different Data Samples")
#plt.xlim(0, 4, 0.2)
#plt.ylim(0, 1, 0.01)

# %% [markdown]
# ### Accuracy Plot of dist=0.122%, 5%, 10% and 20%, sliding windows: 16, 32, 64

# %%
plt.plot(acc1, '', linestyle='dashed', marker='.', label='train(0.122% building pixels with sliding window=16)')
plt.plot(val_acc1, '', linestyle='dashed', marker='.', label='validation(0.122% building pixels with sliding window=16)')

plt.plot(acc2, '', linestyle='dashed', marker='.', label='train(0.122% building pixels with sliding window=32)')
plt.plot(val_acc2, '', linestyle='dashed', marker='.', label='validation(0.122% building pixels with sliding window=32)')

plt.plot(acc3, '', linestyle='dashed', marker='.', label='train(0.122% building pixels with sliding window=64)')
plt.plot(val_acc3, '', linestyle='dashed', marker='.', label='validation(0.122% building pixels with sliding window=64)')

plt.plot(acc4, '', linestyle='dashed', marker='.', label='train(5% building pixels with sliding window=16)')
plt.plot(val_acc4, '', linestyle='dashed', marker='.', label='validation(5% building pixels with sliding window=16)')

#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.19),
          fancybox=True, shadow=True)
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.title("Model Accuracy for different Data Samples")
#plt.xlim(0, 4, 0.2)
#plt.ylim(0, 1, 0.01)

# %%
plt.plot(rec1, prec1, '', linestyle='dashed', label='atleast 0.122% of patch contains building pixels. stride=16, samples=600000')
plt.plot(rec2, prec2, '', linestyle='dashed', label='atleast 0.122% of patch contains building pixels. stride=32')
plt.plot(rec3, prec3, '', linestyle='dashed', label='atleast 0.122% of patch contains building pixels. stride=16, samples=200000')
#plt.plot(rec4, prec4, '', label='atleast 10% of patch contains building pixels')
#plt.plot(rec5, prec5, '', label='5 building pixels in patch with sliding window 32')
#plt.plot(rec6, prec6, '', label='5 building pixels in patch with sliding window 16')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.19),
          fancybox=True, shadow=True)
plt.xlabel('recall')
plt.ylabel('precision')
plt.title("Precision-Recall Curve for Different Class Distribution")
plt.xlim(0, 1, 0.2)
plt.ylim(0, 1, 0.2)
plt.savefig('../data/output/pr.png')

# %%
plt.plot(acc1, '', linestyle='dashed', marker='.', label='train(0.122% building pixels with stride=16, samples=150000)')
plt.plot(val_acc1, '', linestyle='dashed', marker='.', label='validation(0.122% building pixels with stride=16, samples=50000)')

plt.plot(acc2, '', linestyle='dashed', marker='.', label='train(0.122% building pixels with stride=16, samples=480000)')
plt.plot(val_acc2, '', linestyle='dashed', marker='.', label='validation(0.122% building pixels with stride=16, samples=160000)')

#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.19),
          fancybox=True, shadow=True)
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.title("Model Accuracy for different Data Samples")
#plt.xlim(0, 4, 0.2)
#plt.ylim(0, 1, 0.01)
